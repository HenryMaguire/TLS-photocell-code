# %% [markdown]
# # Understanding optical non-additivity
#
# Optical non-additivity is negligible in the limit of sharply peaked lead spectral densities:
# - Strong phonon coupling-dependence on molecule-leads coupling for small SD window dominates behaviour.
# - For small wider lead spectral densities, the phonon coupling
# Here I will find a regime where optical non-additivity is important and could potentially lead to deleterious effects or enhancements.

# %%
# %matplotlib inline
import time 

from qutip import mesolve, steadystate
#from importlib import reload



import numpy as np
import optical as EM
import phonons as RC
import leads as FL
from utils import *
from photocell_setup import *
import matplotlib.pyplot as plt
from style import *
# Out:
# utils imported

# %%
plt.style.use('ggplot')
plt.rcParams["axes.grid"] = True
plt.rc('grid', linestyle="--", color='grey')
plt.rcParams['grid.linestyle'] = "--"
plt.rcParams["axes.edgecolor"] = "0.15"
plt.rcParams["axes.linewidth"]  = 1.3
plt.rcParams['lines.linewidth'] = 2.3
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['font.size'] = 20
plt.rcParams['legend.fontsize'] = 'large'
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath} \usepackage{physics} ')
colours = ['#1E90FF', '#3CB371', '#FFA500', '#FF0000']


colors = [c['color'] for c in plt.rcParams['axes.prop_cycle']]
colors+=colours

# %%
def short_current_from_dict(dd):
    # assumes that V=0 at element 0
    return dd['current'][0]

def calculate_current_slope(binding_energies, alpha_values, lead_SD='Lorentzian', N_max=18, 
                            delta_leads=10e-3, normalise=True, Omega=50e-3):
    
    data = []
    data_add = []
    for BE in binding_energies: #[0., 0.025, 0.05, 0.075, 0.1, 0.2]:
        I_SC = []
        I_SC_add = []
        N_values = [int(n) for n in np.linspace(5,N_max,len(alpha_values))]
        for N, alpha in zip(N_values, alpha_values):
            PARAMS = PARAMS_setup(valence_energy=300e-3, binding_energy=BE, radiative_lifetime=1, 
                                  alpha_ph=alpha, mu=700e-3, bias_voltage=0, N=N, silent=True, 
                                  T_C=300., lead_SD=lead_SD, delta_leads=delta_leads, Omega_ph=Omega)
            #print_PARAMS(PARAMS)
            data_dict = populations_and_current_vs_voltage(PARAMS, x_range=[0.1,0.3],num_voltages=1)
            data_dict_add = additive_populations_and_current_vs_voltage(PARAMS, x_range=[0.1,0.3],num_voltages=1)
            #print(data_dict['current'])
            I_SC.append(short_current_from_dict(data_dict))
            I_SC_add.append(short_current_from_dict(data_dict_add))
            
        data.append(np.array(I_SC))
        data_add.append(np.array(I_SC_add))
        norm1 = norm2 = 1.
        if normalise:
            norm1 = I_SC[0]
            norm2 = I_SC_add[0]
        plt.plot(alpha_values*1000, np.array(I_SC)/norm1, label="Non-additive", color='b') #label='U={}meV'.format(int(BE*100)))
        plt.plot(alpha_values*1000, np.array(I_SC_add)/norm2, label='Additive EM', ls='dashed', color='r')
    plt.xlim(alpha_values[0]*1000, alpha_values[-1]*1000)
    plt.xlabel(r"$\alpha$ $(meV)$")
    plt.ylabel(r"$I_{SC}$ (normalised)")
    plt.axhline(np.array(I_SC)[0]/norm1, label="Additive", color='grey', alpha=0.9)
    plt.legend()
    return np.array(data), np.array(data_add)

def plot_current_slope(alpha_values, data_nonadd, data_add):
    fig, ax = plt.subplots(1, 1, figsize=(7,6), sharex=True)
    norm1 = data_nonadd[0][0]
    norm2 =  data_add[0][0]
    ax.plot(alpha_values*1000, np.array(data_nonadd[0])/norm1, label="Non-additive", color='b') #label='U={}meV'.format(int(BE*100)))
    ax.plot(alpha_values*1000, np.array(data_add[0])/norm2, label='Additive EM', ls='dashed', color='r')
    ax.set_xlim(alpha_values[0]*1000, alpha_values[-1]*1000)
    plt.subplots_adjust(left=0.16, bottom=0.12, right=0.97, top=0.98, wspace=0.24, hspace=0.015)
    ax.set_xlabel(r"$\alpha$ $(meV)$")
    ax.set_ylabel(r"$I_{SC}$ (normalised)")
    ax.axhline(np.array(data_nonadd[0])[0]/norm1, label="Additive", color='grey', alpha=0.9)
    ax.legend()

# %%
#binding_energies = np.linspace(0.05, 0.1, 1)
U=50e-3
binding_energies = [U]
alpha_values = np.linspace(0, 120e-3, 130)
data1, datadd1 = calculate_current_slope(binding_energies, alpha_values, lead_SD='Lorentzian', 
                                       delta_leads=10e-3, N_max=15, normalise=True, Omega=50e-3)
plot_current_slope(alpha_values, data1, datadd1)
plt.savefig("additive_comp_narrow_50.pdf")
# Out:
# C-V data calculated in 3.6 seconds
# C-V data calculated in 3.5 seconds
# C-V data calculated in 4.7 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.9 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.7 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.7 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.5 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.3 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.3 seconds
# C-V data calculated in 4.7 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.4 seconds
# C-V data calculated in 4.7 seconds
# C-V data calculated in 4.5 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.3 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.1 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.2 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.1 seconds
# C-V data calculated in 6.4 seconds
# C-V data calculated in 6.1 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.3 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.4 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.1 seconds
# C-V data calculated in 7.0 seconds
# C-V data calculated in 6.3 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.2 seconds
# C-V data calculated in 6.8 seconds
# C-V data calculated in 6.3 seconds
# C-V data calculated in 9.1 seconds
# C-V data calculated in 8.7 seconds
# C-V data calculated in 9.6 seconds
# C-V data calculated in 8.8 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 8.7 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 9.0 seconds
# C-V data calculated in 9.1 seconds
# C-V data calculated in 8.6 seconds
# C-V data calculated in 9.8 seconds
# C-V data calculated in 8.7 seconds
# C-V data calculated in 9.8 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 10.0 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 9.6 seconds
# C-V data calculated in 8.7 seconds
# C-V data calculated in 9.2 seconds
# C-V data calculated in 8.8 seconds
# C-V data calculated in 9.6 seconds
# C-V data calculated in 8.7 seconds
# C-V data calculated in 9.1 seconds
# C-V data calculated in 8.4 seconds
# C-V data calculated in 9.1 seconds
# C-V data calculated in 8.5 seconds
# C-V data calculated in 12.6 seconds
# C-V data calculated in 12.6 seconds
# C-V data calculated in 12.7 seconds
# C-V data calculated in 12.6 seconds
# C-V data calculated in 12.6 seconds
# C-V data calculated in 12.5 seconds
# C-V data calculated in 12.7 seconds
# C-V data calculated in 12.5 seconds
# C-V data calculated in 12.8 seconds
# C-V data calculated in 12.6 seconds
# C-V data calculated in 12.9 seconds
# C-V data calculated in 12.6 seconds
# C-V data calculated in 12.7 seconds
# C-V data calculated in 12.9 seconds
# C-V data calculated in 13.7 seconds
# C-V data calculated in 13.1 seconds
# C-V data calculated in 12.9 seconds
# C-V data calculated in 13.0 seconds
# C-V data calculated in 12.8 seconds
# C-V data calculated in 12.7 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.3 seconds

# %%
plot_current_slope(alpha_values, data1, datadd1)
plt.savefig("additive_comp_narrow.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-dbd094855523> in <module>()
# ----> 1 plot_current_slope(alpha_values, data1, datadd1)
#       2 plt.savefig("additive_comp_narrow.pdf")
#
# NameError: name 'data1' is not defined

# %%
U=100e-3
binding_energies = [U]
alpha_values = np.linspace(0, 50e-3, 60)
data1, datadd1 = calculate_current_slope(binding_energies, alpha_values, lead_SD='Lorentzian', 
                                       delta_leads=10e-3, N_max=11, normalise=True, Omega=U)
plot_current_slope(alpha_values, data1, datadd1)
plt.savefig("additive_comp_narrow_100.pdf")
# Out:
# C-V data calculated in 3.8 seconds
# C-V data calculated in 4.0 seconds
# C-V data calculated in 5.1 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 5.1 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 5.0 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 5.0 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.9 seconds
# C-V data calculated in 5.0 seconds
# C-V data calculated in 5.8 seconds
# C-V data calculated in 5.0 seconds
# C-V data calculated in 5.2 seconds
# C-V data calculated in 5.7 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 5.9 seconds
# C-V data calculated in 5.7 seconds
# C-V data calculated in 5.7 seconds
# C-V data calculated in 8.1 seconds
# C-V data calculated in 7.5 seconds
# C-V data calculated in 7.9 seconds
# C-V data calculated in 7.3 seconds
# C-V data calculated in 7.8 seconds
# C-V data calculated in 7.3 seconds
# C-V data calculated in 7.7 seconds
# C-V data calculated in 7.4 seconds
# C-V data calculated in 7.6 seconds
# C-V data calculated in 7.3 seconds
# C-V data calculated in 7.8 seconds
# C-V data calculated in 7.1 seconds
# C-V data calculated in 7.9 seconds
# C-V data calculated in 7.1 seconds
# C-V data calculated in 7.8 seconds
# C-V data calculated in 7.3 seconds
# C-V data calculated in 7.7 seconds
# C-V data calculated in 7.5 seconds
# C-V data calculated in 7.7 seconds
# C-V data calculated in 7.4 seconds
# C-V data calculated in 10.9 seconds
# C-V data calculated in 9.9 seconds
# C-V data calculated in 10.9 seconds
# C-V data calculated in 9.9 seconds
# C-V data calculated in 10.9 seconds
# C-V data calculated in 10.1 seconds
# C-V data calculated in 10.8 seconds
# C-V data calculated in 9.9 seconds
# C-V data calculated in 10.9 seconds
# C-V data calculated in 10.0 seconds
# C-V data calculated in 10.9 seconds
# C-V data calculated in 10.2 seconds
# C-V data calculated in 11.3 seconds
# C-V data calculated in 10.3 seconds
# C-V data calculated in 11.3 seconds
# C-V data calculated in 10.0 seconds
# C-V data calculated in 10.7 seconds
# C-V data calculated in 10.0 seconds
# C-V data calculated in 11.0 seconds
# C-V data calculated in 10.0 seconds
# C-V data calculated in 15.2 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 15.1 seconds
# C-V data calculated in 15.3 seconds
# C-V data calculated in 15.1 seconds
# C-V data calculated in 15.4 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 15.1 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 15.1 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 15.1 seconds
# C-V data calculated in 14.9 seconds
# C-V data calculated in 15.2 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 15.5 seconds
# C-V data calculated in 15.9 seconds
# C-V data calculated in 15.1 seconds
# C-V data calculated in 15.0 seconds
# C-V data calculated in 19.8 seconds
# C-V data calculated in 20.0 seconds
# C-V data calculated in 23.4 seconds
# C-V data calculated in 20.7 seconds
# C-V data calculated in 20.4 seconds
# C-V data calculated in 21.5 seconds
# C-V data calculated in 19.2 seconds
# C-V data calculated in 19.9 seconds
# C-V data calculated in 18.9 seconds
# C-V data calculated in 17.3 seconds
# C-V data calculated in 17.2 seconds
# C-V data calculated in 17.2 seconds
# C-V data calculated in 17.4 seconds
# C-V data calculated in 17.4 seconds
# C-V data calculated in 17.3 seconds
# C-V data calculated in 17.4 seconds
# C-V data calculated in 17.4 seconds
# C-V data calculated in 17.3 seconds
# C-V data calculated in 17.2 seconds
# C-V data calculated in 17.3 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 22.4 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.4 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.6 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.6 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 22.4 seconds
# C-V data calculated in 22.6 seconds
# C-V data calculated in 22.7 seconds
# C-V data calculated in 22.5 seconds
# C-V data calculated in 28.4 seconds
# C-V data calculated in 28.4 seconds

# %%
U=120e-3
binding_energies = [U]
alpha_values = np.linspace(0, 120e-3, 130)
data1, datadd1 = calculate_current_slope(binding_energies, alpha_values, lead_SD='Lorentzian', 
                                       delta_leads=10e-3, N_max=15, normalise=True, Omega=U)
plot_current_slope(alpha_values, data1, datadd1)
plt.savefig("additive_comp_narrow_120.pdf")

# %%
U=200e-3
binding_energies = [U]
alpha_values = np.linspace(0, 80e-3, 60)
data1, datadd1 = calculate_current_slope(binding_energies, alpha_values, lead_SD='Lorentzian', 
                                       delta_leads=10e-3, N_max=11, normalise=True, Omega=U)
plot_current_slope(alpha_values, data1, datadd1)
plt.savefig("additive_comp_narrow_200.pdf")
# Out:
# C-V data calculated in 3.7 seconds
# C-V data calculated in 3.7 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.5 seconds
# C-V data calculated in 4.9 seconds
# C-V data calculated in 4.5 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.6 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 4.5 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.4 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 7.0 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 7.0 seconds
# C-V data calculated in 6.5 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.4 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 6.6 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 9.5 seconds
# C-V data calculated in 9.0 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 9.0 seconds
# C-V data calculated in 9.6 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 9.0 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 9.6 seconds
# C-V data calculated in 8.9 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 9.0 seconds
# C-V data calculated in 9.7 seconds
# C-V data calculated in 9.0 seconds
# C-V data calculated in 13.5 seconds
# C-V data calculated in 13.3 seconds
# C-V data calculated in 13.5 seconds
# C-V data calculated in 13.2 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.3 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.3 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.2 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 13.3 seconds
# C-V data calculated in 13.5 seconds
# C-V data calculated in 13.4 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.8 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.6 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.9 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.8 seconds
# C-V data calculated in 17.6 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 17.8 seconds
# C-V data calculated in 17.6 seconds
# C-V data calculated in 17.8 seconds
# C-V data calculated in 17.7 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 22.7 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 23.0 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.9 seconds
# C-V data calculated in 22.7 seconds
# C-V data calculated in 22.7 seconds
# C-V data calculated in 28.9 seconds
# C-V data calculated in 29.0 seconds

# %%
U=120e-3
binding_energies = [U]
alpha_values = np.linspace(0, 120e-3, 50)
data1, datadd1 = calculate_current_slope(binding_energies, alpha_values, lead_SD='flat', 
                                       delta_leads=10e-3, N_max=15, normalise=True, Omega=U)
plot_current_slope(alpha_values, data1, datadd1)
plt.savefig("additive_comp_wide_120.pdf")
# Out:
# C-V data calculated in 4.0 seconds
# C-V data calculated in 3.9 seconds
# C-V data calculated in 5.1 seconds
# C-V data calculated in 4.8 seconds
# C-V data calculated in 5.2 seconds
# C-V data calculated in 4.9 seconds
# C-V data calculated in 4.9 seconds
# C-V data calculated in 4.9 seconds
# C-V data calculated in 7.0 seconds
# C-V data calculated in 6.8 seconds
# C-V data calculated in 7.5 seconds
# C-V data calculated in 6.9 seconds
# C-V data calculated in 7.3 seconds
# C-V data calculated in 7.7 seconds
# C-V data calculated in 7.6 seconds
# C-V data calculated in 7.3 seconds
# C-V data calculated in 10.4 seconds
# C-V data calculated in 9.5 seconds
# C-V data calculated in 10.0 seconds
# C-V data calculated in 9.3 seconds
# C-V data calculated in 10.5 seconds
# C-V data calculated in 9.6 seconds
# C-V data calculated in 10.2 seconds
# C-V data calculated in 9.4 seconds
# C-V data calculated in 13.9 seconds
# C-V data calculated in 13.5 seconds
# C-V data calculated in 13.8 seconds
# C-V data calculated in 14.0 seconds
# C-V data calculated in 14.4 seconds
# C-V data calculated in 14.1 seconds
# C-V data calculated in 14.3 seconds
# C-V data calculated in 14.2 seconds
# C-V data calculated in 18.8 seconds
# C-V data calculated in 18.6 seconds
# C-V data calculated in 18.5 seconds
# C-V data calculated in 17.9 seconds
# C-V data calculated in 18.3 seconds
# C-V data calculated in 18.1 seconds
# C-V data calculated in 23.4 seconds
# C-V data calculated in 23.3 seconds
# C-V data calculated in 24.3 seconds
# C-V data calculated in 24.7 seconds
# C-V data calculated in 23.3 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 22.8 seconds
# C-V data calculated in 23.1 seconds
# C-V data calculated in 29.8 seconds
# C-V data calculated in 29.7 seconds
# C-V data calculated in 32.0 seconds
# C-V data calculated in 30.3 seconds
# C-V data calculated in 29.2 seconds
# C-V data calculated in 28.8 seconds
# C-V data calculated in 29.1 seconds
# C-V data calculated in 29.0 seconds
# C-V data calculated in 37.1 seconds
# C-V data calculated in 37.7 seconds
# C-V data calculated in 37.3 seconds
# C-V data calculated in 37.0 seconds
# C-V data calculated in 36.4 seconds
# C-V data calculated in 36.0 seconds
# C-V data calculated in 37.0 seconds
# C-V data calculated in 36.8 seconds
# C-V data calculated in 47.5 seconds
# C-V data calculated in 50.5 seconds
# C-V data calculated in 48.1 seconds
# C-V data calculated in 46.7 seconds
# C-V data calculated in 47.0 seconds
# C-V data calculated in 46.4 seconds
# C-V data calculated in 57.6 seconds
# C-V data calculated in 57.5 seconds
# C-V data calculated in 59.1 seconds
# C-V data calculated in 58.7 seconds
# C-V data calculated in 57.3 seconds
# C-V data calculated in 56.5 seconds
# C-V data calculated in 57.1 seconds
# C-V data calculated in 56.8 seconds
# C-V data calculated in 72.2 seconds
# C-V data calculated in 72.3 seconds
# C-V data calculated in 72.4 seconds
# C-V data calculated in 72.0 seconds
# C-V data calculated in 73.2 seconds
# C-V data calculated in 72.0 seconds
# C-V data calculated in 72.7 seconds
# C-V data calculated in 72.1 seconds
# C-V data calculated in 89.8 seconds
# C-V data calculated in 89.9 seconds
# C-V data calculated in 90.5 seconds
# C-V data calculated in 89.7 seconds
# C-V data calculated in 90.4 seconds
# C-V data calculated in 89.9 seconds
# C-V data calculated in 90.9 seconds
# C-V data calculated in 90.0 seconds
# C-V data calculated in 113.5 seconds
# C-V data calculated in 112.2 seconds
# C-V data calculated in 113.0 seconds
# C-V data calculated in 111.6 seconds
# C-V data calculated in 112.7 seconds
# C-V data calculated in 112.5 seconds
# C-V data calculated in 141.8 seconds
# C-V data calculated in 139.7 seconds

# %%
binding_energies = [50e-3] #np.linspace(0.0, 0.05, 1)
alpha_values = np.linspace(0, 80e-3, 30)
data, datadd = calculate_current_slope(binding_energies, alpha_values, lead_SD='hat', 
                                       delta_leads=10e-3, N_max=11, normalise=True)
# Out:
# C-V data calculated in 3.9 seconds
# C-V data calculated in 3.6 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9ffe85719b09> in <module>()
#       2 alpha_values = np.linspace(0, 80e-3, 30)
#       3 data, datadd = calculate_current_slope(binding_energies, alpha_values, lead_SD='hat',
# ----> 4                                        delta_leads=10e-3, N_max=11, normalise=True)
#       5 plot_current_slope(alpha_values, data, datadd)
#       6 plt.savefig("additive_comp_wide_50.pdf")
#
# <ipython-input-3-935a7ed53fe9> in calculate_current_slope(binding_energies, alpha_values, lead_SD, N_max, delta_leads, normalise, Omega)
#      17                                   T_C=300., lead_SD=lead_SD, delta_leads=delta_leads, Omega_ph=Omega)
#      18             #print_PARAMS(PARAMS)
# ---> 19             data_dict = populations_and_current_vs_voltage(PARAMS, x_range=[0.1,0.3],num_voltages=1)
#      20             data_dict_add = additive_populations_and_current_vs_voltage(PARAMS, x_range=[0.1,0.3],num_voltages=1)
#      21             #print(data_dict['current'])
#
# /Users/henrymaguire/Work/phd-work/CS-photocell-code/photocell_setup.pyc in populations_and_current_vs_voltage(PARAMS, x_range, num_voltages)
#     207         #if i in [10, 90]:
#     208         #    print_PARAMS(PARAMS)
# --> 209         L_Lindblad_dict = build_L(PARAMS, silent=True)
#     210         #ops = make_expectation_operators(PARAMS)
#     211         n_c = tensor(d_e.dag()*d_e, qeye(PARAMS['N']))
#
# /Users/henrymaguire/Work/phd-work/CS-photocell-code/photocell_setup.pyc in build_L(PARAMS, silent)
#     116         L_EM = EM.L_non_rwa(H_S, A_nrwa, PARAMS['omega_exciton'], PARAMS['Gamma_EM'],
#     117                             PARAMS['T_EM'], PARAMS['J'],
# --> 118                                     silent=silent, tol=0)
#     119         L_EM_add = EM.L_non_rwa(H_add, A_nrwa, PARAMS['omega_exciton'], PARAMS['Gamma_EM'],
#     120                             PARAMS['T_EM'], PARAMS['J'], silent=silent, tol=0)
#
# /Users/henrymaguire/Work/phd-work/CS-photocell-code/optical.pyc in L_non_rwa(H_vib, A, w_0, Gamma, T_EM, J, principal, silent, alpha, tol)
#     150             #print A.matrix_element(eVecs[i].dag(), eVecs[j])
#     151             overlap = A.matrix_element(eVecs[i].dag(), eVecs[j])
# --> 152             s*= A.matrix_element(eVecs[i].dag(), eVecs[j])
#     153             s*= DecayRate(eta, beta, J, Gamma, w_0, imag_part=principal, alpha=alpha, tol=tol)
#     154             G+=s
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/qutip/qobj.pyc in __mul__(self, other)
#     558         elif isinstance(other, (int, float, complex,
#     559                                 np.integer, np.floating, np.complexfloating)):
# --> 560             out = Qobj()
#     561             out.data = self.data * other
#     562             out.dims = self.dims
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/qutip/qobj.pyc in __init__(self, inpt, dims, shape, type, isherm, copy, fast, superrep, isunitary)
#     338             self.superrep = superrep
#     339         else:
# --> 340             if self.type == 'super' and self.superrep is None:
#     341                 self.superrep = 'super'
#     342
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/qutip/qobj.pyc in type(self)
#    1928     def type(self):
#    1929         if not self._type:
# -> 1930             self._type = type_from_dims(self.dims)
#    1931
#    1932         return self._type
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/qutip/dimensions.pyc in type_from_dims(dims, enforce_square)
#      63
#      64 def type_from_dims(dims, enforce_square=True):
# ---> 65     bra_like, ket_like = map(is_scalar, dims)
#      66
#      67     if bra_like:
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/qutip/dimensions.pyc in is_scalar(dims)
#      47     a scalar (has dimension 1).
#      48     """
# ---> 49     return np.prod(flatten(dims)) == 1
#      50
#      51 def is_vector(dims):
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in prod(a, axis, dtype, out, keepdims, initial)
#    2583     """
#    2584     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out, keepdims=keepdims,
# -> 2585                           initial=initial)
#    2586
#    2587
#
# /Users/henrymaguire/.pyenv/versions/2.7.15/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      81                 return reduction(axis=axis, out=out, **passkwargs)
#      82
# ---> 83     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      84
#      85
#
# KeyboardInterrupt:

# %%
plot_current_slope(alpha_values, data, datadd)
plt.savefig("additive_comp_wide_50.pdf")

# %%
def populations_and_current_vs_voltage_all(PARAMS, x_range=[0.,1.4], num_voltages=100, label=''):
    
    if PARAMS['T_L']<100:
        number_of_voltages = int(1.8*num_voltages)
    else:
        number_of_voltages = num_voltages
    bias_voltages = np.concatenate((np.array([0]), 
                                    np.linspace(x_range[0]*ev_to_inv_cm, x_range[1]*ev_to_inv_cm, number_of_voltages)), 
                                   axis=0)
    labels = zip(["L_R", "L_R", "L_R_add", "L_R_add"], # Right lead 
                 ["L", "L_add_EM", "L_add_leads", "L_add"]) #and full dissipators (for current)
    data_dict = {} # inner dicts are of current and population data etc.
    for theory in labels:
        ti = time.time()
        current = []
        conduction_population = []
        valence_population = []
        ground_population = []
        hole_population = []
        electron_population = []
        exciton_population = []
        CC_population = []
        ops = make_expectation_operators(PARAMS)
        for i, bv in enumerate(bias_voltages):
            PARAMS.update({'mu_R': PARAMS['mu']+bv/2, 'mu_L': PARAMS['mu']-bv/2})
            #if i in [10, 90]:
            #    print_PARAMS(PARAMS)
            L_Lindblad_dict = build_L(PARAMS, silent=True)
            #ops = make_expectation_operators(PARAMS)
            n_c = tensor(d_e.dag()*d_e, qeye(PARAMS['N']))
            n_v = tensor(d_h.dag()*d_h, qeye(PARAMS['N']))
            ss = steadystate(L_Lindblad_dict['H_S'], [L_Lindblad_dict[theory[1]]])
            current.append(current_from_ss(ss, L_Lindblad_dict[theory[0]], n_c))
            conduction_population.append((n_c*ss).tr())
            valence_population.append((n_v*ss).tr())
            ground_population.append((ops['vac']*ss).tr())
            hole_population.append((ops['hole']*ss).tr())
            electron_population.append((ops['electron']*ss).tr())
            exciton_population.append((ops['exciton']*ss).tr())
            CC_population.append((ops['CC_pop']*ss).tr())
        data_dict[theory[1]] = {'bias_voltages':bias_voltages/ev_to_inv_cm, 
                     'current': current,
                     'conduction_population' : conduction_population, 
                     'valence_population' : valence_population,
                     'ground_population': ground_population,
                     'hole_population' : hole_population,
                     'electron_population' : electron_population,
                     'exciton_population' : exciton_population,
                     'CC_population' : CC_population,
                    'PARAMS': PARAMS}
        print("C-V {} calculated in {:0.1f} seconds".format(theory[1], time.time() - ti))
    save_obj(data_dict, "DATA/pvp/all_"+label)
    return data_dict

# %%
populations_and_current_vs_voltage_all(PARAMS, x_range=[0.,1.4], num_voltages=30, label='')
